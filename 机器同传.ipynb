# %% [markdown]
# ### 环境安装以及数据模型下载

# %%
# enter baseline directory
# %cd baseline/
# Out:
# /home/aistudio/baseline

# %%
# decompress data, download model, decompress model
# !bash get_data_and_model.sh
# Out:
# Decompress newdata.
# Download w1 model.
# --2021-07-16 07:57:10--  https://paddlenlp.bj.bcebos.com/models/stacl/nist_zhen_full_w1.tar.gz
# Resolving paddlenlp.bj.bcebos.com (paddlenlp.bj.bcebos.com)... 182.61.200.195, 182.61.200.229, 2409:8c00:6c21:10ad:0:ff:b00e:67d, ...
# Connecting to paddlenlp.bj.bcebos.com (paddlenlp.bj.bcebos.com)|182.61.200.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 849058846 (810M) [application/x-gzip]
# Saving to: ‘trained_models/nist_zhen_full_w1.tar.gz’
#
# nist_zhen_full_w1.t 100%[===================>] 809.73M  35.9MB/s    in 23s
#
# 2021-07-16 07:57:33 (35.2 MB/s) - ‘trained_models/nist_zhen_full_w1.tar.gz’ saved [849058846/849058846]
#
# Decompress w1 model.
# Download full sent model.
# --2021-07-16 07:57:45--  https://paddlenlp.bj.bcebos.com/models/stacl/nist_zhen_full_sent.tar.gz
# ...

# %%
# install dependencies
# !pip install -U paddlenlp
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple/
# ...
#      |████████████████████████████████| 440kB 17.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112kB 11.8MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 92kB 22.8MB/s eta 0:00:01
# ...
# ERROR: blackhole 1.0.1 has requirement numpy<=1.19.5, but you'll have numpy 1.20.3 which is incompatible.
# ...
#   Found existing installation: dill 0.3.3
#     Uninstalling dill-0.3.3:
#       Successfully uninstalled dill-0.3.3
#   Found existing installation: paddlenlp 2.0.0rc7
#     Uninstalling paddlenlp-2.0.0rc7:
#       Successfully uninstalled paddlenlp-2.0.0rc7
# ...
# Looking in indexes: https://mirror.baidu.com/pypi/simple/
# ...
#      |████████████████████████████████| 645kB 14.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 890kB 22.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 675kB 13.1MB/s eta 0:00:01
# ...

# %% [markdown]
# ### 中英文同传在wait-1上进行fine-tune并预测
#
# 在finetune_w1.sh中修改一些参数，例如常用的epoch数量和batch_size

# %%
# finetune wait-1 model on transcription training data
# !bash finetune_w1.sh
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# ...

# %% [markdown]
# ### 对finetune的模型进行评估
#
# 这里可以在run_w1.sh中修改参数，例如替换自己finetune的模型

# %%
# test wait-1 sentence translation with transcription
# !bash eval_w1.sh
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# ...

# %% [markdown]
# ### FULL SENTENCE评估

# %%
# test full sentence translation with transcription
# !bash eval_full.sh
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# ...

# %% [markdown]
# ### 中英文ASR翻译

# %%
# test wait-1 sentence translation with ASR
# !bash eval_w1_asr.sh
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# ...

# %% [markdown]
# ### finetune英语-西班牙语transcript翻译
#
# 参考baseline/get_data_and_model.sh， 官方没有提供训练集以及预训练模型。主要是缺少一些必要的文件，暂时未做处理。
